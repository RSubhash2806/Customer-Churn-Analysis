# %% [markdown]
# Loading the Data

# %%
import pandas as pd

# %%
pd.read_csv(r"C:\Users\subha\OneDrive\Documents\Desktop\Customer Churn Analysis\customer_churn_data.csv")
# Out:
#      CustomerID  Age  Gender  Tenure  MonthlyCharges    ContractType  \
# 0             1   49    Male       4           88.35  Month-to-Month
# 1             2   43    Male       0           36.67  Month-to-Month
# 2             3   51  Female       2           63.79  Month-to-Month
# 3             4   60  Female       8          102.34        One-Year
# 4             5   42    Male      32           69.01  Month-to-Month
# ..          ...  ...     ...     ...             ...             ...
# 995         996   42    Male      41           37.14  Month-to-Month
# 996         997   62    Male       9           80.93  Month-to-Month
# 997         998   51  Female      15          111.72  Month-to-Month
# 998         999   39    Male      68           65.67        One-Year
# 999        1000   50    Male       1           56.67  Month-to-Month
#
#     InternetService  TotalCharges TechSupport Churn
# 0       Fiber Optic        353.40         Yes   Yes
# ...

# %%
df = pd.read_csv(r"C:\Users\subha\OneDrive\Documents\Desktop\Customer Churn Analysis\customer_churn_data.csv")

# %%
df
# Out:
#      CustomerID  Age  Gender  Tenure  MonthlyCharges    ContractType  \
# 0             1   49    Male       4           88.35  Month-to-Month
# 1             2   43    Male       0           36.67  Month-to-Month
# 2             3   51  Female       2           63.79  Month-to-Month
# 3             4   60  Female       8          102.34        One-Year
# 4             5   42    Male      32           69.01  Month-to-Month
# ..          ...  ...     ...     ...             ...             ...
# 995         996   42    Male      41           37.14  Month-to-Month
# 996         997   62    Male       9           80.93  Month-to-Month
# 997         998   51  Female      15          111.72  Month-to-Month
# 998         999   39    Male      68           65.67        One-Year
# 999        1000   50    Male       1           56.67  Month-to-Month
#
#     InternetService  TotalCharges TechSupport Churn
# 0       Fiber Optic        353.40         Yes   Yes
# ...

# %%
df.head()
# Out:
#    CustomerID  Age  Gender  Tenure  MonthlyCharges    ContractType  \
# 0           1   49    Male       4           88.35  Month-to-Month
# 1           2   43    Male       0           36.67  Month-to-Month
# 2           3   51  Female       2           63.79  Month-to-Month
# 3           4   60  Female       8          102.34        One-Year
# 4           5   42    Male      32           69.01  Month-to-Month
#
#   InternetService  TotalCharges TechSupport Churn
# 0     Fiber Optic        353.40         Yes   Yes
# 1     Fiber Optic          0.00         Yes   Yes
# 2     Fiber Optic        127.58          No   Yes
# 3             DSL        818.72         Yes   Yes
# 4             NaN       2208.32          No   Yes

# %%
df.tail()
# Out:
#      CustomerID  Age  Gender  Tenure  MonthlyCharges    ContractType  \
# 995         996   42    Male      41           37.14  Month-to-Month
# 996         997   62    Male       9           80.93  Month-to-Month
# 997         998   51  Female      15          111.72  Month-to-Month
# 998         999   39    Male      68           65.67        One-Year
# 999        1000   50    Male       1           56.67  Month-to-Month
#
#     InternetService  TotalCharges TechSupport Churn
# 995     Fiber Optic       1522.74         Yes   Yes
# 996             NaN        728.37          No   Yes
# 997     Fiber Optic       1675.80         Yes   Yes
# 998             NaN       4465.56          No   Yes
# 999             NaN         56.67          No   Yes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CustomerID       1000 non-null   int64
#  1   Age              1000 non-null   int64
#  2   Gender           1000 non-null   object
#  3   Tenure           1000 non-null   int64
#  4   MonthlyCharges   1000 non-null   float64
#  5   ContractType     1000 non-null   object
#  6   InternetService  703 non-null    object
#  7   TotalCharges     1000 non-null   float64
#  8   TechSupport      1000 non-null   object
#  9   Churn            1000 non-null   object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 78.3+ KB

# %%
df.isnull().sum()
# Out:
# CustomerID           0
# Age                  0
# Gender               0
# Tenure               0
# MonthlyCharges       0
# ContractType         0
# InternetService    297
# TotalCharges         0
# TechSupport          0
# Churn                0
# dtype: int64

# %% [markdown]
# Remove all the Null values and Duplicate values

# %%
df["InternetService"]
# Out:
# 0      Fiber Optic
# 1      Fiber Optic
# 2      Fiber Optic
# 3              DSL
# 4              NaN
#           ...
# 995    Fiber Optic
# 996            NaN
# 997    Fiber Optic
# 998            NaN
# 999            NaN
# Name: InternetService, Length: 1000, dtype: object

# %%
df["InternetService"] = df["InternetService"].fillna("")

# %%
df["InternetService"]
# Out:
# 0      Fiber Optic
# 1      Fiber Optic
# 2      Fiber Optic
# 3              DSL
# 4
#           ...
# 995    Fiber Optic
# 996
# 997    Fiber Optic
# 998
# 999
# Name: InternetService, Length: 1000, dtype: object

# %%
df.isnull().sum()
# Out:
# CustomerID         0
# Age                0
# Gender             0
# Tenure             0
# MonthlyCharges     0
# ContractType       0
# InternetService    0
# TotalCharges       0
# TechSupport        0
# Churn              0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Correlation Values

# %%
numeric_columns_data = df.select_dtypes(include = ["number"])

# %%
numeric_columns_data.corr()
# Out:
#                 CustomerID       Age    Tenure  MonthlyCharges  TotalCharges
# CustomerID        1.000000  0.036730 -0.018585       -0.030504     -0.027490
# Age               0.036730  1.000000  0.000472        0.006362     -0.001896
# Tenure           -0.018585  0.000472  1.000000       -0.014552      0.894868
# MonthlyCharges   -0.030504  0.006362 -0.014552        1.000000      0.304893
# TotalCharges     -0.027490 -0.001896  0.894868        0.304893      1.000000

# %% [markdown]
# If the correlation value is 1, then it is Strongly Positive
# If the correlation value is -1, then it is Strongly Negative

# %%
#Now, lets have a detailed conclusion about the dataset we have!
df.describe()
# Out:
#         CustomerID          Age      Tenure  MonthlyCharges  TotalCharges
# count  1000.000000  1000.000000  1000.00000     1000.000000   1000.000000
# mean    500.500000    44.674000    18.97300       74.391290   1404.364060
# std     288.819436     9.797741    18.89257       25.712083   1571.755048
# min       1.000000    12.000000     0.00000       30.000000      0.000000
# 25%     250.750000    38.000000     5.00000       52.357500    345.217500
# 50%     500.500000    45.000000    13.00000       74.060000    872.870000
# 75%     750.250000    51.000000    26.00000       96.102500   1900.175000
# max    1000.000000    83.000000   122.00000      119.960000  12416.250000

# %%
df
# Out:
#      CustomerID  Age  Gender  Tenure  MonthlyCharges    ContractType  \
# 0             1   49    Male       4           88.35  Month-to-Month
# 1             2   43    Male       0           36.67  Month-to-Month
# 2             3   51  Female       2           63.79  Month-to-Month
# 3             4   60  Female       8          102.34        One-Year
# 4             5   42    Male      32           69.01  Month-to-Month
# ..          ...  ...     ...     ...             ...             ...
# 995         996   42    Male      41           37.14  Month-to-Month
# 996         997   62    Male       9           80.93  Month-to-Month
# 997         998   51  Female      15          111.72  Month-to-Month
# 998         999   39    Male      68           65.67        One-Year
# 999        1000   50    Male       1           56.67  Month-to-Month
#
#     InternetService  TotalCharges TechSupport Churn
# 0       Fiber Optic        353.40         Yes   Yes
# ...

# %% [markdown]
# Data Visualization

# %%
df["Churn"].value_counts()
#It returns the number of yes or no values in the churn attribute!
# Out:
# Churn
# Yes    883
# No     117
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
df["Churn"].value_counts().plot(kind = "pie")
plt.title("Churn(Yes/N0)?")
plt.ylabel(" ")
plt.show()

# %%
df.head()
# Out:
#    CustomerID  Age  Gender  Tenure  MonthlyCharges    ContractType  \
# 0           1   49    Male       4           88.35  Month-to-Month
# 1           2   43    Male       0           36.67  Month-to-Month
# 2           3   51  Female       2           63.79  Month-to-Month
# 3           4   60  Female       8          102.34        One-Year
# 4           5   42    Male      32           69.01  Month-to-Month
#
#   InternetService  TotalCharges TechSupport Churn
# 0     Fiber Optic        353.40         Yes   Yes
# 1     Fiber Optic          0.00         Yes   Yes
# 2     Fiber Optic        127.58          No   Yes
# 3             DSL        818.72         Yes   Yes
# 4                       2208.32          No   Yes

# %%
df.groupby("Churn")["MonthlyCharges"].mean()
# Out:
# Churn
# No     62.54641
# Yes    75.96077
# Name: MonthlyCharges, dtype: float64

# %% [markdown]
# As we can see, the value of the churn increases at Higher means than at the lower means

# %%
df.groupby(["Churn","Gender"])["MonthlyCharges"].mean()
# Out:
# Churn  Gender
# No     Female    65.091912
#        Male      59.013878
# Yes    Female    74.975064
#        Male      77.082518
# Name: MonthlyCharges, dtype: float64

# %%
df.groupby("Churn")["Tenure"].mean()
# Out:
# Churn
# No     30.264957
# Yes    17.476784
# Name: Tenure, dtype: float64

# %%
df.groupby("Churn")["Age"].mean()
# Out:
# Churn
# No     43.487179
# Yes    44.831257
# Name: Age, dtype: float64

# %% [markdown]
# There is no significant difference between the age groups

# %%
df.head(5)
# Out:
#    CustomerID  Age  Gender  Tenure  MonthlyCharges    ContractType  \
# 0           1   49    Male       4           88.35  Month-to-Month
# 1           2   43    Male       0           36.67  Month-to-Month
# 2           3   51  Female       2           63.79  Month-to-Month
# 3           4   60  Female       8          102.34        One-Year
# 4           5   42    Male      32           69.01  Month-to-Month
#
#   InternetService  TotalCharges TechSupport Churn
# 0     Fiber Optic        353.40         Yes   Yes
# 1     Fiber Optic          0.00         Yes   Yes
# 2     Fiber Optic        127.58          No   Yes
# 3             DSL        818.72         Yes   Yes
# 4                       2208.32          No   Yes

# %%
df.groupby("ContractType")["MonthlyCharges"].mean()
# Out:
# ContractType
# Month-to-Month    75.909198
# One-Year          73.822803
# Two-Year          71.334500
# Name: MonthlyCharges, dtype: float64

# %% [markdown]
# We can notice that at lower term contracts there are higher churns!

# %%
df.groupby("ContractType")["MonthlyCharges"].mean().plot(kind = "bar")
plt.title("Visualization of Churn based on Contract-Type")
plt.ylabel("Mean of Monthly Charges")
plt.show()

# %%
df
# Out:
#      CustomerID  Age  Gender  Tenure  MonthlyCharges    ContractType  \
# 0             1   49    Male       4           88.35  Month-to-Month
# 1             2   43    Male       0           36.67  Month-to-Month
# 2             3   51  Female       2           63.79  Month-to-Month
# 3             4   60  Female       8          102.34        One-Year
# 4             5   42    Male      32           69.01  Month-to-Month
# ..          ...  ...     ...     ...             ...             ...
# 995         996   42    Male      41           37.14  Month-to-Month
# 996         997   62    Male       9           80.93  Month-to-Month
# 997         998   51  Female      15          111.72  Month-to-Month
# 998         999   39    Male      68           65.67        One-Year
# 999        1000   50    Male       1           56.67  Month-to-Month
#
#     InternetService  TotalCharges TechSupport Churn
# 0       Fiber Optic        353.40         Yes   Yes
# ...

# %%
plt.hist(df["MonthlyCharges"])
plt.title("Histogram of Monthly Charges")
plt.show()

# %%
plt.hist(df["Tenure"])
plt.title("Histogram of Tenure")
plt.show()

# %% [markdown]
# Feature Engineering

# %%
df.columns
# Out:
# Index(['CustomerID', 'Age', 'Gender', 'Tenure', 'MonthlyCharges',
#        'ContractType', 'InternetService', 'TotalCharges', 'TechSupport',
#        'Churn'],
#       dtype='object')

# %%
y = df[["Churn"]]
x = df[["Age", "Gender", "Tenure", "MonthlyCharges"]]

# %%
x
# Out:
#      Age  Gender  Tenure  MonthlyCharges
# 0     49    Male       4           88.35
# 1     43    Male       0           36.67
# 2     51  Female       2           63.79
# 3     60  Female       8          102.34
# 4     42    Male      32           69.01
# ..   ...     ...     ...             ...
# 995   42    Male      41           37.14
# 996   62    Male       9           80.93
# 997   51  Female      15          111.72
# 998   39    Male      68           65.67
# 999   50    Male       1           56.67
#
# [1000 rows x 4 columns]

# %%
y
# Out:
#     Churn
# 0     Yes
# 1     Yes
# 2     Yes
# 3     Yes
# 4     Yes
# ..    ...
# 995   Yes
# 996   Yes
# 997   Yes
# 998   Yes
# 999   Yes
#
# [1000 rows x 1 columns]

# %%
x["Gender"]
# Out:
# 0        Male
# 1        Male
# 2      Female
# 3      Female
# 4        Male
#         ...
# 995      Male
# 996      Male
# 997    Female
# 998      Male
# 999      Male
# Name: Gender, Length: 1000, dtype: object

# %%
x["Gender"].apply(lambda x:1 if x == "Female" else 0)
# Out:
# 0      0
# 1      0
# 2      1
# 3      1
# 4      0
#       ..
# 995    0
# 996    0
# 997    1
# 998    0
# 999    0
# Name: Gender, Length: 1000, dtype: int64

# %%
x["Gender"] = x["Gender"].apply(lambda x:1 if x == "Female" else 0)
# Out:
# C:\Users\subha\AppData\Local\Temp\ipykernel_3328\3459503666.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x["Gender"] = x["Gender"].apply(lambda x:1 if x == "Female" else 0)

# %%
x["Gender"]
# Out:
# 0      0
# 1      0
# 2      1
# 3      1
# 4      0
#       ..
# 995    0
# 996    0
# 997    1
# 998    0
# 999    0
# Name: Gender, Length: 1000, dtype: int64

# %%
x.head()
# Out:
#    Age  Gender  Tenure  MonthlyCharges  False
# 0   49       0       4           88.35      1
# 1   43       0       0           36.67      1
# 2   51       1       2           63.79      1
# 3   60       1       8          102.34      1
# 4   42       0      32           69.01      1

# %% [markdown]
# Gender : 1 -> Female,
#          0 -> Male

# %%
type(x["Gender"][0])
# Out:
# numpy.int64

# %%
y.head(5)
# Out:
#   Churn
# 0   Yes
# 1   Yes
# 2   Yes
# 3   Yes
# 4   Yes

# %%
y["Churn"].apply(lambda y:1 if y == "Yes" else 0)
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 995    1
# 996    1
# 997    1
# 998    1
# 999    1
# Name: Churn, Length: 1000, dtype: int64

# %%
y["Churn"] = y["Churn"].apply(lambda y:1 if y == "Yes" else 0)
# Out:
# C:\Users\subha\AppData\Local\Temp\ipykernel_3328\456255831.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y["Churn"] = y["Churn"].apply(lambda y:1 if y == "Yes" else 0)

# %%
y["Churn"]
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 995    1
# 996    1
# 997    1
# 998    1
# 999    1
# Name: Churn, Length: 1000, dtype: int64

# %%
y["Churn"].value_counts()
# Out:
# Churn
# 1    883
# 0    117
# Name: count, dtype: int64

# %% [markdown]
# Churn : 1 -> Yes, 0 -> No

# %%
y
# Out:
#      Churn
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
# ..     ...
# 995      1
# 996      1
# 997      1
# 998      1
# 999      1
#
# [1000 rows x 1 columns]

# %%
x
# Out:
#      Age  Gender  Tenure  MonthlyCharges  False
# 0     49       0       4           88.35      1
# 1     43       0       0           36.67      1
# 2     51       1       2           63.79      1
# 3     60       1       8          102.34      1
# 4     42       0      32           69.01      1
# ..   ...     ...     ...             ...    ...
# 995   42       0      41           37.14      1
# 996   62       0       9           80.93      1
# 997   51       1      15          111.72      1
# 998   39       0      68           65.67      1
# 999   50       0       1           56.67      1
#
# [1000 rows x 5 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2)

# %%
x
# Out:
#      Age  Gender  Tenure  MonthlyCharges  False
# 0     49       0       4           88.35      1
# 1     43       0       0           36.67      1
# 2     51       1       2           63.79      1
# 3     60       1       8          102.34      1
# 4     42       0      32           69.01      1
# ..   ...     ...     ...             ...    ...
# 995   42       0      41           37.14      1
# 996   62       0       9           80.93      1
# 997   51       1      15          111.72      1
# 998   39       0      68           65.67      1
# 999   50       0       1           56.67      1
#
# [1000 rows x 5 columns]

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
x_train = scaler.fit_transform(x_train)

# %%
import joblib
joblib.dump(scaler, "scaler.pkl")
# Out:
# ['scaler.pkl']

# %%
x_test = scaler.fit_transform(x_test)

# %%
x_train
# Out:
# array([[ 1.384023  , -1.11114215, -0.47835163, -0.77019116,  0.        ],
#        [ 1.07668999,  0.89997486,  0.81065842,  0.69998658,  0.        ],
#        [ 0.66691264, -1.11114215, -0.01430801,  0.73021961,  0.        ],
#        ...,
#        [-0.15264206, -1.11114215,  2.40903089, -0.51514846,  0.        ],
#        [ 1.58891168, -1.11114215,  0.39817521, -1.19422871,  0.        ],
#        [ 0.15469095, -1.11114215, -0.94239525,  0.2724606 ,  0.        ]],
#       shape=(800, 5))

# %%
x_test
# Out:
# array([[-0.04148364,  1.040833  ,  0.19518996,  1.11516884,  0.        ],
#        [-0.04148364,  1.040833  , -0.64692391, -0.65171789,  0.        ],
#        [ 1.27385114,  1.040833  ,  1.09745483,  0.2710643 ,  0.        ],
#        [ 0.46441436, -0.96076892, -1.00782985, -0.70706901,  0.        ],
#        [-0.34502243,  1.040833  , -1.06798084,  0.85343713,  0.        ],
#        [ 1.17267154,  1.040833  , -0.76722589, -0.70865047,  0.        ],
#        [ 1.37503074, -0.96076892, -1.06798084, -0.93598541,  0.        ],
#        [ 0.16087556, -0.96076892,  2.24032365,  0.1611528 ,  0.        ],
#        [-0.44620203, -0.96076892, -0.46647093,  0.56600669,  0.        ],
#        [ 0.66677355,  1.040833  ,  0.73654888, -0.94310199,  0.        ],
#        [-1.45799801,  1.040833  ,  1.03730384, -0.74186114,  0.        ],
#        [ 0.16087556,  1.040833  , -0.58677291, -1.51796287,  0.        ],
#        [ 0.97031235,  1.040833  , -0.88752787, -1.61364123,  0.        ],
# ...

# %%
from sklearn.metrics import accuracy_score

# %%
def modelperformance(predictions):
    print("Accuracy score of the model is {}".format(accuracy_score(y_test, predictions)))

# %%
from sklearn.model_selection import GridSearchCV

# %%
  from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
model.fit(x_train, y_train)
import warnings
warnings.filterwarnings('ignore')

# %%
model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
x
# Out:
#      Age  Gender  Tenure  MonthlyCharges  False
# 0     49       0       4           88.35      1
# 1     43       0       0           36.67      1
# 2     51       1       2           63.79      1
# 3     60       1       8          102.34      1
# 4     42       0      32           69.01      1
# ..   ...     ...     ...             ...    ...
# 995   42       0      41           37.14      1
# 996   62       0       9           80.93      1
# 997   51       1      15          111.72      1
# 998   39       0      68           65.67      1
# 999   50       0       1           56.67      1
#
# [1000 rows x 5 columns]

# %%
y
# Out:
#      Churn
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
# ..     ...
# 995      1
# 996      1
# 997      1
# 998      1
# 999      1
#
# [1000 rows x 1 columns]

# %%
x.columns = x.columns.astype(str)
x.drop('False', axis=1, inplace=True)

# %%
x
# Out:
#      Age  Gender  Tenure  MonthlyCharges
# 0     49       0       4           88.35
# 1     43       0       0           36.67
# 2     51       1       2           63.79
# 3     60       1       8          102.34
# 4     42       0      32           69.01
# ..   ...     ...     ...             ...
# 995   42       0      41           37.14
# 996   62       0       9           80.93
# 997   51       1      15          111.72
# 998   39       0      68           65.67
# 999   50       0       1           56.67
#
# [1000 rows x 4 columns]

# %%
y_pred = model.predict(x_test)

# %%
y_test
# Out:
#      Churn
# 535      1
# 419      1
# 314      1
# 999      1
# 465      1
# ..     ...
# 900      0
# 842      0
# 325      1
# 672      1
# 821      1
#
# [200 rows x 1 columns]

# %%
modelperformance(y_pred)
# Out:
# Accuracy score of the model is 0.875

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
param_grid = {
    "n_neighbors" : [3, 5, 7, 9],
    "weights" : ["uniform", "distance"],
}

# %%
gridkn = GridSearchCV(KNeighborsClassifier(), param_grid, cv = 5)

# %%
gridkn.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=KNeighborsClassifier(),
#              param_grid={'n_neighbors': [3, 5, 7, 9],
#                          'weights': ['uniform', 'distance']})

# %%
gridkn.best_params_
# Out:
# {'n_neighbors': 9, 'weights': 'uniform'}

# %%
y_pred = gridkn.predict(x_tet)

# %%
modelperformance(y_pred)
# Out:
# Accuracy score of the model is 0.88

# %%
from sklearn.svm import SVC

# %%
svm = SVC()

# %%
param_grid = {
    "C" : [0.01, 0.1, 0.5, 1],
    "kernel" : ["linear", "rbf", "poly"]
}

# %%
gridsvc = GridSearchCV(svm, param_grid, cv = 5)

# %%
gridsvc.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=SVC(),
#              param_grid={'C': [0.01, 0.1, 0.5, 1],
#                          'kernel': ['linear', 'rbf', 'poly']})

# %%
y_pred = gridsvc.predict(x_test)

# %%
modelperformance(y_pred)
# Out:
# Accuracy score of the model is 0.885

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
param_grid = {
    "criterion" : ["gene", "entropy"],
    "splitter" : ["best", "random"],
    "max_depth" : [None, 10, 20, 30],
    "min_samples_split" : [2, 5, 10],
    "min_samples_leaf" : [1, 2, 4]
}

# %%
grid_tree = GridSearchCV(DecisionTreeClassifier(), param_grid, cv = 5)

# %%
grid_tree.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gene', 'entropy'],
#                          'max_depth': [None, 10, 20, 30],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'splitter': ['best', 'random']})

# %%
y_pred = grid_tree.predict(x_test)

# %%
modelperformance(y_pred)
# Out:
# Accuracy score of the model is 0.865

# %%
from sklearn.ensemble import RandomForestClassifier
rfc_model = RandomForestClassifier()

# %%
param_grid = {
    "n_estimators" : [32, 64, 128, 256],
    "max_features" : [2, 3, 4],
    "bootstrap" : [True, False]
}

# %%
grid_rfc = GridSearchCV(rfc_model, param_grid, cv = 5)

# %%
grid_rfc.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'bootstrap': [True, False], 'max_features': [2, 3, 4],
#                          'n_estimators': [32, 64, 128, 256]})

# %%
grid_rfc.best_params_
# Out:
# {'bootstrap': True, 'max_features': 2, 'n_estimators': 64}

# %%
y_pred = grid_rfc.predict(x_test)

# %%
modelperformance(y_pred)
# Out:
# Accuracy score of the model is 0.87

# %%
best_model = gridsvc.best_estimator_

# %%
joblib.dump(best_model, "model.pkl")
# Out:
# ['model.pkl']

# %%
x.columns
# Out:
# Index(['Age', 'Gender', 'Tenure', 'MonthlyCharges'], dtype='object')

# %%
import subprocess

subprocess.run(["python", "app.py"])
# Out:
# CompletedProcess(args=['python', 'app.py'], returncode=0)
